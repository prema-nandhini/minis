# %%
import pandas as pd
food=pd.read_csv('E:\indian_food.csv')
food.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
food.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %%
cols=[x.upper() for x in food.columns]
cols
# Out:
# ['NAME',
#  'INGREDIENTS',
#  'DIET',
#  'PREP_TIME',
#  'COOK_TIME',
#  'FLAVOR_PROFILE',
#  'COURSE',
#  'STATE',
#  'REGION']

# %%
food.isnull()
# Out:
#       name  ingredients   diet  prep_time  cook_time  flavor_profile  course  \
# 0    False        False  False      False      False           False   False
# 1    False        False  False      False      False           False   False
# 2    False        False  False      False      False           False   False
# 3    False        False  False      False      False           False   False
# 4    False        False  False      False      False           False   False
# ..     ...          ...    ...        ...        ...             ...     ...
# 250  False        False  False      False      False           False   False
# 251  False        False  False      False      False           False   False
# 252  False        False  False      False      False           False   False
# 253  False        False  False      False      False           False   False
# 254  False        False  False      False      False           False   False
#
#      state  region
# 0    False   False
# ...

# %%
food.isnull().any()
# Out:
# name              False
# ingredients       False
# diet              False
# prep_time         False
# cook_time         False
# flavor_profile    False
# course            False
# state             False
# region             True
# dtype: bool

# %%
food.fillna(0)
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
food[(food['diet']=='vegetarian') & (food['region']=='South') & (food['state']=='Tamil Nadu')]
# Out:
#                      name                                        ingredients  \
# 49                 Pongal                       Rice, jaggery, cashews, ghee
# 53             Unni Appam               Rice flour, banana, jaggery, coconut
# 127  Currivepillai sadam   Chana dal, urad dal, fresh coconut, sesame see...
# 129              Idiappam              Rice flour, hot water, grated coconut
# 132        Kaara kozhambu  Sesame oil, drumstick, tamarind paste, sambar ...
# 133          Keerai kootu  Moong dal, chana dal, spinach, urad dal, cocon...
# 134        Keerai masiyal  Urad dal, curry leaves, sugar, mustard seeds, ...
# 135          Keerai sadam     Greens, tomato, mustard seeds, fenugreek seeds
# 136        Keerai poriyal  Amaranth leaves, split urad dal, mustard seeds...
# 138                 Kootu           Chana dal, urad dal, potato, beans, peas
# 139             Kos kootu  Moong dal, chana dal, cabbage, tamarind, curry...
# ...

# %%
tn=food[(food['diet']=='vegetarian') & (food['region']=='South') & (food['state']=='Tamil Nadu')]
tn.reset_index()
# Out:
#     index                  name  \
# 0      49                Pongal
# 1      53            Unni Appam
# 2     127  Currivepillai sadam
# 3     129              Idiappam
# 4     132        Kaara kozhambu
# 5     133          Keerai kootu
# 6     134        Keerai masiyal
# 7     135          Keerai sadam
# 8     136        Keerai poriyal
# 9     138                 Kootu
# 10    139             Kos kootu
# 11    141       Kothamali sadam
# 12    142          Kuzhakkattai
# 13    143              Kuzhambu
# 14    146             Paniyaram
# 15    150         Paruppu sadam
# 16    152               Poriyal
# 17    153            Puli sadam
# 18    159          Thayir sadam
#
#                                           ingredients        diet  prep_time  \
# 0                        Rice, jaggery, cashews, ghee  vegetarian          5
# 1                Rice flour, banana, jaggery, coconut  vegetarian         10
# ...

# %%
tn[food['flavor_profile']=='sweet'].reset_index()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#    index        name                           ingredients        diet  \
# 0     49      Pongal          Rice, jaggery, cashews, ghee  vegetarian
# 1     53  Unni Appam  Rice flour, banana, jaggery, coconut  vegetarian
#
#    prep_time  cook_time flavor_profile   course       state region
# 0          5         20          sweet  dessert  Tamil Nadu  South
# 1         10         20          sweet  dessert  Tamil Nadu  South

# %%
nv=food.groupby('diet')
nv.get_group('non vegetarian').reset_index()
# Out:
#     index                  name  \
# 0      64            Maach Jhol
# 1      65           Pork Bharta
# 2      67                 Galho
# 3      75               Biryani
# 4      76        Butter chicken
# 5      79        Chicken razala
# 6      80  Chicken Tikka masala
# 7      81         Chicken Tikka
# 8     122      Tandoori Chicken
# 9     123   Tandoori Fish Tikka
# 10    137              Beef Fry
# 11    163       Chicken Varuval
# 12    167           Kolim Jawla
# 13    172            Bombil fry
# 14    211              Vindaloo
# 15    223           Kumol Sawul
# 16    225            Alu Pitika
# 17    226           Masor tenga
# 18    228           Bilahi Maas
# 19    229            Black rice
# 20    232   Chingri malai curry
# 21    235              Haq Maas
# 22    236         Chingri Bhape
# 23    237              Kabiraji
# 24    239        Koldil Chicken
# 25    240             Konir Dom
# 26    241           Koldil Duck
# 27    242            Masor Koni
# ...

# %%
g=food.loc[food['prep_time']>100]
g.reset_index(inplace=True)
g
# Out:
#     index                 name  \
# 0      29            Misti doi
# 1      33            Ras malai
# 2      46       Obbattu holige
# 3      48             Poornalu
# 4      66       Chak Hao Kheer
# 5      81        Chicken Tikka
# 6     114          Pindi chana
# 7     122     Tandoori Chicken
# 8     123  Tandoori Fish Tikka
# 9     124                 Attu
# 10    128                 Dosa
# 11    129             Idiappam
# 12    130                 Idli
# 13    144          Masala Dosa
# 14    151            Pesarattu
# 15    155                Puttu
# 16    157              Sandige
# 17    158                Sevai
#
#                                           ingredients            diet  \
# 0                                       Milk, jaggery      vegetarian
# 1                     Chhena, reduced milk, pistachio      vegetarian
# 2   Maida flour, turmeric, coconut, chickpeas, jag...      vegetarian
# 3                                  Chana dal, jaggery      vegetarian
# ...

# %%
g
# Out:
#     index                 name  \
# 0      29            Misti doi
# 1      33            Ras malai
# 2      46       Obbattu holige
# 3      48             Poornalu
# 4      66       Chak Hao Kheer
# 5      81        Chicken Tikka
# 6     114          Pindi chana
# 7     122     Tandoori Chicken
# 8     123  Tandoori Fish Tikka
# 9     124                 Attu
# 10    128                 Dosa
# 11    129             Idiappam
# 12    130                 Idli
# 13    144          Masala Dosa
# 14    151            Pesarattu
# 15    155                Puttu
# 16    157              Sandige
# 17    158                Sevai
#
#                                           ingredients            diet  \
# 0                                       Milk, jaggery      vegetarian
# 1                     Chhena, reduced milk, pistachio      vegetarian
# 2   Maida flour, turmeric, coconut, chickpeas, jag...      vegetarian
# 3                                  Chana dal, jaggery      vegetarian
# ...

# %%
food[:10]
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian         45         25          sweet  dessert    West Bengal
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(food['prep_time'])

# %%
food1=food[:10]
plt.plot(food1['prep_time'])

# %%
import numpy as np
x=food.head()
x
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
x1=x['name']
x1
# Out:
# 0        Balu shahi
# 1            Boondi
# 2    Gajar ka halwa
# 3            Ghevar
# 4       Gulab jamun
# Name: name, dtype: object

# %%
name=np.arange(len(x1))
name
# Out:
# array([0, 1, 2, 3, 4])

# %%
y1=x['prep_time']
y1
# Out:
# 0    45
# 1    80
# 2    15
# 3    15
# 4    15
# Name: prep_time, dtype: int64

# %%
plt.bar(name,y1)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.xticks(name,x1)
plt.bar(name,y1)
plt.xlabel('food')
plt.ylabel('preparing_time')
plt.title('foods and their preparing time')
# Out:
# Text(0.5, 1.0, 'foods and their preparing time')
